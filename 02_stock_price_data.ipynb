# %% [markdown]
# # Preparing Price Data

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

from pathlib import Path
import requests
from io import BytesIO
from zipfile import ZipFile, BadZipFile
import time
import itertools
from collections import Counter
from datetime import datetime, timedelta
from tqdm import tqdm
import json

import numpy as np
import pandas as pd
from sklearn.datasets import fetch_openml

import yfinance as yf

import datasets

# %%
sec_path = Path('sec-edgar-10k')

data_store = sec_path / 'assets.h5'
sec_parsed_data_path = sec_path / 'parsed-data'
companies_data_path = sec_path / 'subset-companies'

DAYS_BEFORE = 93
DAYS_AFTER = 31

# %% [markdown]
# ## Quandl Wiki Prices

# %% [markdown]
# > Quandl has been [acuqired by NASDAQ](https://www.nasdaq.com/about/press-center/nasdaq-acquires-quandl-advance-use-alternative-data) in late 2018. In 2021, NASDAQ [integrated Quandl's data platform](https://data.nasdaq.com/). Free US equity data is still available under a [new URL](https://data.nasdaq.com/databases/WIKIP/documentation), subject to the limitations mentioned below.
#
# [NASDAQ](https://data.nasdaq.com/) makes available a [dataset](/home/stefan/drive/machine-learning-for-trading/data/create_datasets.ipynb) with stock prices, dividends and splits for 3,000 US publicly-traded companies. Prior to its acquisition (April 11, 2018), Quandl announced the end of community support (updates). The historical data are useful as a first step towards demonstrating the application of the machine learning solutions, just ensure you design and test your own algorithms using current, professional-grade data.

# %% [markdown]
# 1. Follow the instructions to create a free [NASDAQ account](https://data.nasdaq.com/sign-up)
# 2. [Download](https://data.nasdaq.com/tables/WIKIP/WIKI-PRICES/export) the entire WIKI/PRICES data
# 3. Extract the .zip file
# 4. Move to this directory and rename to wiki_prices.csv
# 5. Run the below code to store in fast HDF format

# %%
df = pd.read_csv(sec_path / 'wiki_prices.csv', parse_dates=['date'], index_col=['date', 'ticker'], infer_datetime_format=True).sort_index()
df.info()

with pd.HDFStore(data_store) as store:
    store.put('quandl/wiki/prices', df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 15389314 entries, (Timestamp('1962-01-02 00:00:00'), 'ARNC') to (Timestamp('2018-03-27 00:00:00'), 'ZUMZ')
# Data columns (total 12 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   open         float64
#  1   high         float64
#  2   low          float64
#  3   close        float64
#  4   volume       float64
#  5   ex-dividend  float64
#  6   split_ratio  float64
#  7   adj_open     float64
#  8   adj_high     float64
#  9   adj_low      float64
#  10  adj_close    float64
#  11  adj_volume   float64
# dtypes: float64(12)
# memory usage: 1.4+ GB
# None

# %% [markdown]
# ### Wiki Prices Metadata

# %% [markdown]
# Quandl used to make some stock meta data be available on its website. Instead of using the Quandl API, load the file `wiki_stocks.csv` as described and store in HDF5 format.

# %%
df = pd.read_csv(sec_path / 'wiki_stocks.csv')
df.info()

with pd.HDFStore(data_store) as store:
    store.put('quandl/wiki/stocks', df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3199 entries, 0 to 3198
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   code    3199 non-null   object
#  1   name    3199 non-null   object
# dtypes: object(2)
# memory usage: 50.1+ KB
# None

# %% [markdown]
# ## Metadata on US Companies

# %%
df = pd.read_csv(sec_path / 'us_equities_meta_data.csv')
df.info()

with pd.HDFStore(data_store) as store:
    store.put('us_equities/stocks', df.set_index('ticker'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6834 entries, 0 to 6833
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ticker     6834 non-null   object
#  1   name       6834 non-null   object
#  2   lastsale   6718 non-null   float64
#  3   marketcap  5766 non-null   float64
#  4   ipoyear    3038 non-null   float64
#  5   sector     5288 non-null   object
#  6   industry   5288 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 373.9+ KB

# %% [markdown]
# ## Download and Persist Stock Prices and SEC Filings Info
#
# Here we only download price data for those companies whose `cik` exist in the SEC 10-K filing dataset for the available filing years only.

# %%
filing_index = pd.read_csv(sec_path / 'filing_index.csv', parse_dates=['DATE_FILED']).rename(columns=str.lower)
filing_index.index += 1

# %%
cik_year = set([tuple(f[1].values) for f in filing_index[['cik', 'year']].iterrows()])

# %%
dataset = datasets.load_from_disk(sec_parsed_data_path)
train_parsed = dataset['train']

# %%
filtered = train_parsed.filter(lambda example: (int(example['cik']), int(example['year'])) in cik_year)

# %%
filing_filtered = filing_index.loc[filing_index.cik.astype(str).isin(filtered['cik']), :]

# %%
filing_filtered.head()
# Out:
#        cik                  company_name form_type date_filed  \
# 1  1000180                  SANDISK CORP      10-K 2013-02-19
# 2  1000209      MEDALLION FINANCIAL CORP      10-K 2013-03-13
# 3  1000228              HENRY SCHEIN INC      10-K 2013-02-13
# 4  1000229         CORE LABORATORIES N V      10-K 2013-02-19
# 5  1000232  KENTUCKY BANCSHARES INC  KY       10-K 2013-03-28
#
#                                     edgar_link  quarter ticker   sic exchange  \
# 1  edgar/data/1000180/0001000180-13-000009.txt        1   SNDK  3572   NASDAQ
# 2  edgar/data/1000209/0001193125-13-103504.txt        1   TAXI  6199   NASDAQ
# 3  edgar/data/1000228/0001000228-13-000010.txt        1   HSIC  5047   NASDAQ
# 4  edgar/data/1000229/0001000229-13-000009.txt        1    CLB  1389     NYSE
# 5  edgar/data/1000232/0001104659-13-025094.txt        1   KTYB  6022      OTC
#
#   hits  year
# 1    3  2013
# 2    0  2013
# 3    3  2013
# 4    2  2013
# 5    0  2013

# %% [markdown]
# ### Download stock price data using Yfinance

# %%
def yfinance_download(symbol, cik, filing_dates, days_before, days_after):
    prices = []
    ticker = yf.Ticker(symbol)
    
    for filing, date in filing_dates.to_dict().items():
        start = date - timedelta(days=days_before)
        end = date + timedelta(days=days_after)
        
        try:
            df = ticker.history(start=start, end=end)
        except:
            print("Yfinance lost connection...")
            return []
            
        prices.append(df.assign(ticker=symbol, cik=cik, filing=filing))

    return prices

# %%
print(f"Storing stock price data for {len(filing_filtered.ticker.unique())} tickers between years {filing_filtered.year.min()}-{filing_filtered.year.max()}:")
# Out:
# Storing stock price data for 6219 tickers between years 2013-2016:

# %%
yf_data, missing, lost = [], [], []

for i, (symbol, dates) in tqdm(enumerate(filing_filtered.groupby('ticker').date_filed, 1)):
    cik = filing_filtered.loc[filing_filtered.ticker == symbol, 'cik'].iloc[0]
    
    price_hist = yfinance_download(symbol, cik, dates, days_before=DAYS_BEFORE, days_after=DAYS_AFTER)

    if not price_hist:
        lost.append(symbol)
    elif price_hist[0].empty:
        missing.append(symbol)
    else:
        yf_data.append(price_hist)

    time.sleep(0.5)
# Out:
# 2it [00:02,  1.06s/it]AAC: Data doesn't exist for startDate = 1372478400, endDate = 1383192000
# AAC: Data doesn't exist for startDate = 1403928000, endDate = 1414641600
# AAC: Data doesn't exist for startDate = 1436673600, endDate = 1447390800
# 6it [00:04,  1.27it/s]AAMC: Data doesn't exist for startDate = 1352178000, endDate = 1362891600
# AAMC: Data doesn't exist for startDate = 1384837200, endDate = 1395547200
# AAMC: Data doesn't exist for startDate = 1417237200, endDate = 1427947200
# AAMC: Data doesn't exist for startDate = 1448686800, endDate = 1459396800
# 8it [00:06,  1.27it/s]AAN: Data doesn't exist for startDate = 1353474000, endDate = 1364184000
# AAN: Data doesn't exist for startDate = 1385182800, endDate = 1395892800
# AAN: Data doesn't exist for startDate = 1417237200, endDate = 1427947200
# AAN: Data doesn't exist for startDate = 1448686800, endDate = 1459396800
# 12it [00:09,  1.22it/s]AAPH: No timezone found, symbol may be delisted
# AAPH: No timezone found, symbol may be delisted
# 14it [00:11,  1.23it/s]AARI: No price data found, symbol may be delisted (1d 2013-07-28 00:00:00 -> 2013-11-29 00:00:00)
# AARI: No price data found, symbol may be delisted (1d 2014-08-09 00:00:00 -> 2014-12-11 00:00:00)
# AARI: No price data found, symbol may be delisted (1d 2015-08-01 00:00:00 -> 2015-12-03 00:00:00)
# AARI: No price data found, symbol may be delisted (1d 2016-07-30 00:00:00 -> 2016-12-01 00:00:00)
# 15it [00:12,  1.27it/s]AARS: No timezone found, symbol may be delisted
# AARS: No timezone found, symbol may be delisted
# 18it [00:14,  1.31it/s]AAVL: Data doesn't exist for startDate = 1417496400, endDate = 1428206400
# AAVL: Data doesn't exist for startDate = 1449032400, endDate = 1459742400
# 27it [00:21,  1.26it/s]ABCR: No price data found, symbol may be delisted (1d 2013-05-07 00:00:00 -> 2013-09-08 00:00:00)
# 28it [00:22,  1.37it/s]ABCW: No price data found, symbol may be delisted (1d 2013-02-24 00:00:00 -> 2013-06-28 00:00:00)
# ABCW: No price data found, symbol may be delisted (1d 2014-12-16 00:00:00 -> 2015-04-19 00:00:00)
# ABCW: No price data found, symbol may be delisted (1d 2015-12-09 00:00:00 -> 2016-04-11 00:00:00)
# 29it [00:22,  1.39it/s]ABFS: No price data found, symbol may be delisted (1d 2012-11-27 00:00:00 -> 2013-03-31 00:00:00)
# ABFS: No price data found, symbol may be delisted (1d 2013-11-27 00:00:00 -> 2014-03-31 00:00:00)
# ABFS: No price data found, symbol may be delisted (1d 2014-11-29 00:00:00 -> 2015-04-02 00:00:00)
# ABFS: No price data found, symbol may be delisted (1d 2015-11-25 00:00:00 -> 2016-03-28 00:00:00)
# 31it [00:24,  1.34it/s]ABH: No price data found, symbol may be delisted (1d 2013-11-30 00:00:00 -> 2014-04-03 00:00:00)
# ABH: No price data found, symbol may be delisted (1d 2014-11-29 00:00:00 -> 2015-04-02 00:00:00)
# ABH: No price data found, symbol may be delisted (1d 2015-11-28 00:00:00 -> 2016-03-31 00:00:00)
# 32it [00:25,  1.32it/s]ABHD: No timezone found, symbol may be delisted
# ABHD: No timezone found, symbol may be delisted
# ABHD: No timezone found, symbol may be delisted
# ABHD: No timezone found, symbol may be delisted
# 40it [00:31,  1.20it/s]ABRM: No price data found, symbol may be delisted (1d 2013-06-29 00:00:00 -> 2013-10-31 00:00:00)
# 42it [00:33,  1.20it/s]ABTL: No price data found, symbol may be delisted (1d 2012-11-27 00:00:00 -> 2013-03-31 00:00:00)
No price data found, symbol may be delisted (1d 2014-12-28 00:00:00 -> 2015-05-01 00:00:00)
# ACCP: No price data found, symbol may be delisted (1d 2015-12-28 00:00:00 -> 2016-04-30 00:00:00)
# 54it [00:41,  1.36it/s]ACE: Data doesn't exist for startDate = 1353992400, endDate = 1364702400
# ACE: Data doesn't exist for startDate = 1385528400, endDate = 1396238400
# ACE: Data doesn't exist for startDate = 1416978000, endDate = 1427688000
# ACE: Data doesn't exist for startDate = 1448427600, endDate = 1459137600
# 55it [00:42,  1.33it/s]ACET: Data doesn't exist for startDate = 1369713600, endDate = 1380427200
# ACET: Data doesn't exist for startDate = 1401854400, endDate = 1412568000
# ACET: Data doesn't exist for startDate = 1433908800, endDate = 1444622400
# ACET: Data doesn't exist for startDate = 1464148800, endDate = 1474862400
# 61it [00:47,  1.16it/s]ACHN: Data doesn't exist for startDate = 1353301200, endDate = 1364011200
# ACHN: Data doesn't exist for startDate = 1386133200, endDate = 1396843200
# ACHN: Data doesn't exist for startDate = 1417496400, endDate = 1428206400
# ACHN: Data doesn't exist for startDate = 1448341200, endDate = 1459051200
# 62it [00:48,  1.12it/s]ACI: Data doesn't exist for startDate = 1354078800, endDate = 1364788800
# ACI: Data doesn't exist for startDate = 1385528400, endDate = 1396238400
# ACI: Data doesn't exist for startDate = 1416978000, endDate = 1427688000
# ACI: Data doesn't exist for startDate = 1449982800, endDate = 1460692800
# 64it [00:50,  1.18it/s]ACLO: No price data found, symbol may be delisted (1d 2013-01-13 00:00:00 -> 2013-05-17 00:00:00)
# ACLO: No price data found, symbol may be delisted (1d 2014-01-13 00:00:00 -> 2014-05-17 00:00:00)
# ACLO: No price data found, symbol may be delisted (1d 2015-01-13 00:00:00 -> 2015-05-17 00:00:00)
# ACLO: No price data found, symbol may be delisted (1d 2016-06-11 00:00:00 -> 2016-10-13 00:00:00)
# 67it [00:52,  1.19it/s]ACMC: No timezone found, symbol may be delisted
# ACMC: No timezone found, symbol may be delisted
# ACMC: No timezone found, symbol may be delisted
# ACMC: No timezone found, symbol may be delisted
# 68it [00:53,  1.32it/s]ACMP: No price data found, symbol may be delisted (1d 2012-11-24 00:00:00 -> 2013-03-28 00:00:00)
# ACMP: No price data found, symbol may be delisted (1d 2013-11-20 00:00:00 -> 2014-03-24 00:00:00)
# ACMP: No price data found, symbol may be delisted (1d 2014-11-24 00:00:00 -> 2015-03-28 00:00:00)
# ACMP: No price data found, symbol may be delisted (1d 2015-11-25 00:00:00 -> 2016-03-28 00:00:00)
# 71it [00:56,  1.08it/s]ACO: No price data found, symbol may be delisted (1d 2013-01-07 00:00:00 -> 2013-05-11 00:00:00)
# ACO: No price data found, symbol may be delisted (1d 2013-11-30 00:00:00 -> 2014-04-03 00:00:00)
# 73it [00:57,  1.18it/s]ACPW: No price data found, symbol may be delisted (1d 2012-12-01 00:00:00 -> 2013-04-04 00:00:00)
# ACPW: No price data found, symbol may be delisted (1d 2013-12-01 00:00:00 -> 2014-04-04 00:00:00)
# ACPW: No price data found, symbol may be delisted (1d 2014-11-26 00:00:00 -> 2015-03-30 00:00:00)
# ACPW: No price data found, symbol may be delisted (1d 2015-11-22 00:00:00 -> 2016-03-25 00:00:00)
# 75it [00:59,  1.14it/s]ACRI: Data doesn't exist for startDate = 1356238800, endDate = 1366948800
# ACRI: Data doesn't exist for startDate = 1387947600, endDate = 1398657600
# 76it [01:00,  1.16it/s]ACRO: Data doesn't exist for startDate = 1375156800, endDate = 1385874000
# ACRO: Data doesn't exist for startDate = 1379736000, endDate = 1390453200
# ACRO: Data doesn't exist for startDate = 1410321600, endDate = 1421038800
# ACRO: Data doesn't exist for startDate = 1444708800, endDate = 1455426000
# ACRO: Data doesn't exist for startDate = 1456203600, endDate = 1466913600
# 79it [01:02,  1.24it/s]ACSF: No timezone found, symbol may be delisted
# ACSF: No timezone found, symbol may be delisted
# 80it [01:03,  1.35it/s]ACT: Data doesn't exist for startDate = 1385269200, endDate = 1395979200
# ACT: Data doesn't exist for startDate = 1416200400, endDate = 1426910400
# ACT: Data doesn't exist for startDate = 1448427600, endDate = 1459137600
# 81it [01:04,  1.36it/s]ACTC: No timezone found, symbol may be delisted
# ACTC: No timezone found, symbol may be delisted
# ACTC: No timezone found, symbol may be delisted
# ACTC: No timezone found, symbol may be delisted
# ACTC: No timezone found, symbol may be delisted
# ACTC: No timezone found, symbol may be delisted
# ACTC: No timezone found, symbol may be delisted
# 83it [01:05,  1.37it/s]ACTU: No price data found, symbol may be delisted (1d 2012-12-05 00:00:00 -> 2013-04-08 00:00:00)
# ACTU: No price data found, symbol may be delisted (1d 2013-12-04 00:00:00 -> 2014-04-07 00:00:00)
# 86it [01:08,  1.22it/s]ACW: No price data found, symbol may be delisted (1d 2012-12-15 00:00:00 -> 2013-04-18 00:00:00)
# ACW: No price data found, symbol may be delisted (1d 2013-12-03 00:00:00 -> 2014-04-06 00:00:00)
# ACW: No price data found, symbol may be delisted (1d 2014-11-30 00:00:00 -> 2015-04-03 00:00:00)
# ACW: No price data found, symbol may be delisted (1d 2015-11-28 00:00:00 -> 2016-03-31 00:00:00)
# 87it [01:08,  1.21it/s]ACXM: No price data found, symbol may be delisted (1d 2013-02-25 00:00:00 -> 2013-06-29 00:00:00)
# ACXM: No price data found, symbol may be delisted (1d 2014-02-24 00:00:00 -> 2014-06-28 00:00:00)
# ACXM: No price data found, symbol may be delisted (1d 2015-02-23 00:00:00 -> 2015-06-27 00:00:00)
# ACXM: No price data found, symbol may be delisted (1d 2016-02-24 00:00:00 -> 2016-06-27 00:00:00)
# 88it [01:09,  1.22it/s]ACY: No timezone found, symbol may be delisted
# ACY: No timezone found, symbol may be delisted
# ACY: No timezone found, symbol may be delisted
# ACY: No timezone found, symbol may be delisted
# ACY: No timezone found, symbol may be delisted
# 89it [01:10,  1.33it/s]ADAC: No timezone found, symbol may be delisted
# ADAC: No timezone found, symbol may be delisted
# ADAC: No timezone found, symbol may be delisted
# ADAC: No timezone found, symbol may be delisted
# 90it [01:10,  1.44it/s]ADAT: No price data found, symbol may be delisted (1d 2013-06-25 00:00:00 -> 2013-10-27 00:00:00)
# ADAT: No price data found, symbol may be delisted (1d 2014-06-28 00:00:00 -> 2014-10-30 00:00:00)
# ADAT: No price data found, symbol may be delisted (1d 2015-07-12 00:00:00 -> 2015-11-13 00:00:00)
# 91it [01:11,  1.38it/s]ADB: Data doesn't exist for startDate = 1353992400, endDate = 1364702400
# ADB: Data doesn't exist for startDate = 1385269200, endDate = 1395979200
# ADB: Data doesn't exist for startDate = 1416805200, endDate = 1427515200
# ADB: Data doesn't exist for startDate = 1448254800, endDate = 1458964800
# 95it [01:15,  1.18it/s]ADEP: No price data found, symbol may be delisted (1d 2013-06-19 00:00:00 -> 2013-10-21 00:00:00)
# ADEP: No price data found, symbol may be delisted (1d 2014-05-24 00:00:00 -> 2014-09-25 00:00:00)
# ADEP: No price data found, symbol may be delisted (1d 2015-05-30 00:00:00 -> 2015-10-01 00:00:00)
# 97it [01:16,  1.24it/s]ADGE: No price data found, symbol may be delisted (1d 2012-12-29 00:00:00 -> 2013-05-02 00:00:00)
# ADGE: No price data found, symbol may be delisted (1d 2014-01-06 00:00:00 -> 2014-05-10 00:00:00)
# ADGE: No price data found, symbol may be delisted (1d 2014-12-28 00:00:00 -> 2015-05-01 00:00:00)
# ADGE: No price data found, symbol may be delisted (1d 2015-12-28 00:00:00 -> 2016-04-30 00:00:00)
# 98it [01:17,  1.25it/s]ADGL: Data doesn't exist for startDate = 1356757200, endDate = 1367467200
# ADGL: Data doesn't exist for startDate = 1388206800, endDate = 1398916800
# 99it [01:18,  1.29it/s]ADHXF: No price data found, symbol may be delisted (1d 2012-12-29 00:00:00 -> 2013-05-02 00:00:00)
# ADHXF: No price data found, symbol may be delisted (1d 2013-12-28 00:00:00 -> 2014-05-01 00:00:00)
# ADHXF: No price data found, symbol may be delisted (1d 2014-12-28 00:00:00 -> 2015-05-01 00:00:00)
# ADHXF: No price data found, symbol may be delisted (1d 2015-12-26 00:00:00 -> 2016-04-28 00:00:00)
# 101it [01:20,  1.19it/s]ADK: Data doesn't exist for startDate = 1365220800, endDate = 1375934400
# ADK: Data doesn't exist for startDate = 1388206800, endDate = 1398916800
# ADK: Data doesn't exist for startDate = 1419742800, endDate = 1430452800
# ADK: Data doesn't exist for startDate = 1451278800, endDate = 1461988800
# 103it [01:21,  1.18it/s]ADMA: Data doesn't exist for startDate = 1354510800, endDate = 1365220800
# 104it [01:22,  1.19it/s]ADMC: No timezone found, symbol may be delisted
# ADMC: No timezone found, symbol may be delisted
# ADMC: No timezone found, symbol may be delisted
# 105it [01:23,  1.30it/s]ADMD: No price data found, symbol may be delisted (1d 2012-12-26 00:00:00 -> 2013-04-29 00:00:00)
# ADMD: No price data found, symbol may be delisted (1d 2013-12-28 00:00:00 -> 2014-05-01 00:00:00)
# ADMD: No price data found, symbol may be delisted (1d 2015-01-12 00:00:00 -> 2015-05-16 00:00:00)
# ADMD: No price data found, symbol may be delisted (1d 2016-02-22 00:00:00 -> 2016-06-25 00:00:00)
# 106it [01:24,  1.29it/s]ADMS: No timezone found, symbol may be delisted
# ADMS: No timezone found, symbol may be delisted
# 107it [01:24,  1.41it/s]ADNC: No price data found, symbol may be delisted (1d 2012-12-01 00:00:00 -> 2013-04-04 00:00:00)
# ADNC: No price data found, symbol may be delisted (1d 2013-12-11 00:00:00 -> 2014-04-14 00:00:00)
# ADNC: No price data found, symbol may be delisted (1d 2014-12-06 00:00:00 -> 2015-04-09 00:00:00)
# 110it [01:27,  1.21it/s]ADPT: Data doesn't exist for startDate = 1354942800, endDate = 1365652800
# ADPT: Data doesn't exist for startDate = 1386565200, endDate = 1397275200
# ADPT: Data doesn't exist for startDate = 1418446800, endDate = 1429156800
# ADPT: Data doesn't exist for startDate = 1449637200, endDate = 1460347200
# 111it [01:27,  1.23it/s]ADRO: No timezone found, symbol may be delisted
# 112it [01:28,  1.36it/s]ADRV: No timezone found, symbol may be delisted
# ADRV: No timezone found, symbol may be delisted
# ADRV: No timezone found, symbol may be delisted
# ADRV: No timezone found, symbol may be delisted
# 113it [01:28,  1.45it/s]ADS: No timezone found, symbol may be delisted
# ADS: No timezone found, symbol may be delisted
# AMIC: No price data found, symbol may be delisted (1d 2014-12-13 00:00:00 -> 2015-04-16 00:00:00)
# AMIC: No price data found, symbol may be delisted (1d 2016-03-05 00:00:00 -> 2016-07-07 00:00:00)
# 288it [03:48,  1.26it/s]AMID: Data doesn't exist for startDate = 1358053200, endDate = 1368763200
# AMID: Data doesn't exist for startDate = 1386478800, endDate = 1397188800
# AMID: Data doesn't exist for startDate = 1417928400, endDate = 1428638400
# AMID: Data doesn't exist for startDate = 1449291600, endDate = 1460001600
# 295it [03:55,  1.07it/s]AMPD: Data doesn't exist for startDate = 1357707600, endDate = 1368417600
# AMPD: Data doesn't exist for startDate = 1389502800, endDate = 1400212800
# AMPD: Data doesn't exist for startDate = 1419656400, endDate = 1430366400
# AMPD: Data doesn't exist for startDate = 1450846800, endDate = 1461556800
# 298it [03:57,  1.20it/s]AMRB: No timezone found, symbol may be delisted
# AMRB: No timezone found, symbol may be delisted
# AMRB: No timezone found, symbol may be delisted
# AMRB: No timezone found, symbol may be delisted
# 300it [03:58,  1.30it/s]AMRI: No price data found, symbol may be delisted (1d 2012-12-15 00:00:00 -> 2013-04-18 00:00:00)
# AMRI: No price data found, symbol may be delisted (1d 2013-12-14 00:00:00 -> 2014-04-17 00:00:00)
# AMRI: No price data found, symbol may be delisted (1d 2014-12-13 00:00:00 -> 2015-04-16 00:00:00)
# AMRI: No price data found, symbol may be delisted (1d 2015-12-28 00:00:00 -> 2016-04-30 00:00:00)
# 304it [04:02,  1.15it/s]AMRZ: No timezone found, symbol may be delisted
# AMRZ: No timezone found, symbol may be delisted
# 308it [04:05,  1.18it/s]AMSG: No price data found, symbol may be delisted (1d 2012-11-26 00:00:00 -> 2013-03-30 00:00:00)
# AMSG: No price data found, symbol may be delisted (1d 2013-11-25 00:00:00 -> 2014-03-29 00:00:00)
# AMSG: No price data found, symbol may be delisted (1d 2014-11-26 00:00:00 -> 2015-03-30 00:00:00)
# AMSG: No price data found, symbol may be delisted (1d 2015-11-24 00:00:00 -> 2016-03-27 00:00:00)
# 312it [04:09,  1.10it/s]AMTD: Data doesn't exist for startDate = 1377057600, endDate = 1387774800
# AMTD: Data doesn't exist for startDate = 1408507200, endDate = 1419224400
# AMTD: Data doesn't exist for startDate = 1439956800, endDate = 1450674000
# AMTD: Data doesn't exist for startDate = 1471406400, endDate = 1482123600
# 313it [04:09,  1.14it/s]AMTG: No price data found, symbol may be delisted (1d 2012-12-04 00:00:00 -> 2013-04-07 00:00:00)
# AMTG: No price data found, symbol may be delisted (1d 2013-11-20 00:00:00 -> 2014-03-24 00:00:00)
# AMTG: No price data found, symbol may be delisted (1d 2014-11-18 00:00:00 -> 2015-03-22 00:00:00)
# AMTG: No price data found, symbol may be delisted (1d 2015-12-02 00:00:00 -> 2016-04-04 00:00:00)
# 316it [04:12,  1.16it/s]AMZG: No price data found, symbol may be delisted (1d 2013-01-13 00:00:00 -> 2013-05-17 00:00:00)
# AMZG: No price data found, symbol may be delisted (1d 2013-12-25 00:00:00 -> 2014-04-28 00:00:00)
# AMZG: No price data found, symbol may be delisted (1d 2014-12-28 00:00:00 -> 2015-05-01 00:00:00)
No price data found, symbol may be delisted (1d 2014-12-28 00:00:00 -> 2015-05-01 00:00:00)
# ZTM: No price data found, symbol may be delisted (1d 2016-01-12 00:00:00 -> 2016-05-15 00:00:00)
# 6216it [1:22:18,  1.26it/s]ZU: No timezone found, symbol may be delisted
# ZU: No timezone found, symbol may be delisted
# 6218it [1:22:20,  1.32it/s]ZYNX: No price data found, symbol may be delisted (1d 2012-12-25 00:00:00 -> 2013-04-28 00:00:00)
# ZYNX: No price data found, symbol may be delisted (1d 2013-12-25 00:00:00 -> 2014-04-28 00:00:00)
# ZYNX: No price data found, symbol may be delisted (1d 2014-12-28 00:00:00 -> 2015-05-01 00:00:00)
# ZYNX: No price data found, symbol may be delisted (1d 2015-12-29 00:00:00 -> 2016-05-01 00:00:00)
# 6219it [1:22:20,  1.26it/s]

# %%
yf_data = itertools.chain.from_iterable(yf_data)

# %%
yf_data = pd.concat(yf_data).rename(columns=str.lower)

# %%
yf_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 884210 entries, 2013-09-17 00:00:00-04:00 to 2016-04-13 00:00:00-04:00
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   open           884207 non-null  float64
#  1   high           884207 non-null  float64
#  2   low            884207 non-null  float64
#  3   close          884207 non-null  float64
#  4   volume         884210 non-null  float64
#  5   dividends      884210 non-null  float64
#  6   stock splits   884210 non-null  float64
#  7   ticker         884210 non-null  object
#  8   cik            884210 non-null  int64
#  9   filing         884210 non-null  int64
#  10  capital gains  53119 non-null   float64
#  11  adj close      0 non-null       float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 87.7+ MB

# %%
yf_data.drop(columns=['dividends', 'stock splits', 'capital gains', 'adj close'], inplace=True)

# %%
yf_data.to_hdf(sec_path / 'sec_returns.h5', 'data/yfinance')

# %%
print(f"{len(missing)} ticker price data are missing. Try to retrieve from Quandl stock prices:")
# Out:
# 3422 ticker price data are missing. Try to retrieve from Quandl stock prices:

# %% [markdown]
# ### Get missing prices from Quandl if exist

# %%
to_do = filing_filtered.loc[~filing_filtered.ticker.isin(yf_data.ticker.unique()), ['ticker', 'date_filed']]

# %%
min_year = to_do.date_filed.min().year

# %%
quandl_tickers = pd.read_hdf(data_store, 'quandl/wiki/prices').loc[pd.IndexSlice[f'{min_year}':, :], :].index.unique('ticker')
quandl_tickers = list(set(quandl_tickers).intersection(set(to_do.ticker)))

# %%
print(f"Found {len(quandl_tickers)} ticker price data in Quandl stock prices.")
# Out:
# Found 1230 ticker price data in Quandl stock prices.

# %%
to_do = filing_filtered.loc[filing_filtered.ticker.isin(quandl_tickers), ['ticker', 'date_filed']]

# %%
ohlcv = ['adj_open', 'adj_high', 'adj_low', 'adj_close', 'adj_volume']

# %%
quandl = pd.read_hdf(data_store, 'quandl/wiki/prices').loc[pd.IndexSlice[f'{min_year}': , quandl_tickers], ohlcv].rename(columns=lambda x: x.replace('adj_', ''))

# %%
quandl_data = []

for i, (symbol, dates) in tqdm(enumerate(to_do.groupby('ticker').date_filed, 1)):
    cik = filing_filtered.loc[filing_filtered.ticker == symbol, 'cik'].iloc[0]
        
    for filing, date in dates.to_dict().items():
        start = date - timedelta(days=DAYS_BEFORE)
        end = date + timedelta(days=DAYS_AFTER)
        try:
            quandl_data.append(quandl.loc[pd.IndexSlice[start:end, symbol], :].reset_index('ticker').assign(cik=cik, filing=filing))
        except:
            continue
        
quandl_data = pd.concat(quandl_data)
# Out:
# 1230it [00:09, 129.86it/s]

# %%
quandl_data.to_hdf(sec_path / 'sec_returns.h5', 'data/quandl')

# %% [markdown]
# ### Combine, clean and persist

# %%
data = pd.concat(
    [
        pd.read_hdf(sec_path / 'sec_returns.h5', 'data/yfinance'),
        pd.read_hdf(sec_path / 'sec_returns.h5', 'data/quandl')
    ],
    axis=0
)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1228824 entries, 2013-09-17 00:00:00-04:00 to 2015-01-23 00:00:00
# Data columns (total 8 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   open    1228802 non-null  float64
#  1   high    1228820 non-null  float64
#  2   low     1228820 non-null  float64
#  3   close   1228821 non-null  float64
#  4   volume  1228824 non-null  float64
#  5   ticker  1228824 non-null  object
#  6   cik     1228824 non-null  int64
#  7   filing  1228824 non-null  int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 84.4+ MB

# %%
data = data.loc[:, ['filing', 'ticker', 'cik', 'open', 'high', 'low', 'close', 'volume']]

# %%
data.to_hdf(sec_path / 'sec_returns.h5', 'prices')

# %% [markdown]
# ### Create a subset of companies for out-of-sample return predictions [Optional]

# %%
SUBSET_TICKERS = ["AAPL", "MSFT", "AMZN", "WMT", "XOM", "PZZA", "VIPS", "AX", "UHS", "SMCI", "HEES", "KAR", "TNC", "SD", "VNET"]

# %%
json_file = open(sec_path / 'company_tickers.json', 'r')
tickers = json.load(json_file)
json_file.close()

tickers = pd.DataFrame(tickers).T
tickers = tickers.loc[tickers.ticker.isin(SUBSET_TICKERS)].reset_index(drop=True)
tickers['cik_url'] = tickers.cik_str.apply(
    lambda cik: [f"https://data.sec.gov/submissions/CIK{cik:010d}.json",
                 f"https://data.sec.gov/submissions/CIK{cik:010d}-submissions-001.json"]
)
tickers['cik'] = tickers.cik_str.astype(int)
tickers.cik_str = tickers.cik_str.apply(lambda cik: f"CIK{cik:010d}")

# %%
df_10k = pd.DataFrame()

for cik in tickers.cik_str.to_list():
    cik_int = tickers.loc[tickers.cik_str==cik].cik.values[0]
    ticker = tickers.loc[tickers.cik_str==cik].ticker.values[0]
    try:
        json_file = open((companies_data_path / f'{cik}.json').as_posix(), 'r')
        values = json.load(json_file)
        json_file.close()
        df = pd.DataFrame(values['filings']['recent'])
    except Exception as e:
        print(f"File {ticker}:{cik}.json does not exist.")
        continue

    try:
        json_file = open((companies_data_path / f'{cik}-submissions-001.json').as_posix(), 'r')
        values = json.load(json_file)
        json_file.close()
        df = pd.concat([df, pd.DataFrame(values)], axis=0)
    except Exception as e:
        print(f"File {ticker}:{cik}-submissions-001.json does not exist.")

    df = df[df.form == '10-K']['filingDate']
    df.reset_index(drop=True, inplace=True)
    df = pd.concat(
        [df,
         pd.Series([cik_int] * df.shape[0], name='cik'),
         pd.Series([ticker] * df.shape[0], name='ticker'),
        ],
        axis=1
    )
    df_10k = pd.concat([df_10k, df], axis=0)
df_10k.filingDate = pd.to_datetime(df_10k.filingDate)
# Out:
# File SMCI:CIK0001375365-submissions-001.json does not exist.
# File VIPS:CIK0001529192-submissions-001.json does not exist.
# File VNET:CIK0001508475-submissions-001.json does not exist.

# %%
df_10k.groupby('cik').min().set_index('ticker').join(df_10k.groupby('cik').max().set_index('ticker'), lsuffix='_start', rsuffix='_end')
# Out:
#        filingDate_start filingDate_end
# ticker
# XOM          2004-03-15     2023-02-22
# TNC          2002-03-29     2023-02-23
# WMT          2006-03-29     2023-03-17
# AAPL         1994-12-13     2022-10-28
# UHS          1994-03-30     2023-02-27
# MSFT         2006-08-25     2023-07-27
# PZZA         1997-03-31     2023-02-23
# AMZN         1999-03-05     2023-02-03
# AX           2005-09-16     2022-09-08
# HEES         2006-03-24     2023-02-22
# SD           2008-03-07     2023-03-15
# SMCI         2009-08-31     2022-08-29
# KAR          2009-03-11     2023-03-09

# %%
df_10k = df_10k.loc[(df_10k.filingDate.dt.year >= 2010) & (df_10k.filingDate.dt.year <= 2020)]

# %%
yf_data, missing, lost = [], [], []

for i, (symbol, dates) in tqdm(enumerate(df_10k.groupby('ticker').filingDate, 1)):
    cik = df_10k.loc[df_10k.ticker == symbol, 'cik'].iloc[0]
    
    price_hist = yfinance_download(symbol, cik, dates, days_before=DAYS_BEFORE, days_after=DAYS_AFTER)

    if not price_hist:
        lost.append(symbol)
    elif price_hist[0].empty:
        missing.append(symbol)
    else:
        yf_data.append(price_hist)

    time.sleep(0.5)
# Out:
# 7it [00:10,  1.48s/it]SD: Data doesn't exist for startDate = 1451278800, endDate = 1461988800
# SD: Data doesn't exist for startDate = 1416978000, endDate = 1427688000
# SD: Data doesn't exist for startDate = 1385528400, endDate = 1396238400
# SD: Data doesn't exist for startDate = 1354078800, endDate = 1364788800
# SD: Data doesn't exist for startDate = 1322283600, endDate = 1332993600
# SD: Data doesn't exist for startDate = 1290834000, endDate = 1301544000
# SD: Data doesn't exist for startDate = 1259384400, endDate = 1270094400
# 13it [00:20,  1.59s/it]

# %%
yf_data = itertools.chain.from_iterable(yf_data)

# %%
yf_data = pd.concat(yf_data).rename(columns=str.lower)

# %%
yf_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11455 entries, 2020-07-29 00:00:00-04:00 to 2010-03-26 00:00:00-04:00
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   open          11455 non-null  float64
#  1   high          11455 non-null  float64
#  2   low           11455 non-null  float64
#  3   close         11455 non-null  float64
#  4   volume        11455 non-null  float64
#  5   dividends     11455 non-null  float64
#  6   stock splits  11455 non-null  float64
#  7   ticker        11455 non-null  object
#  8   cik           11455 non-null  int64
#  9   filing        11455 non-null  int64
#  10  adj close     0 non-null      float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
yf_data.drop(columns=['dividends', 'stock splits', 'adj close'], inplace=True)

# %%
yf_data.to_hdf(sec_path / 'sec_returns.h5', 'data/subset/yfinance')
